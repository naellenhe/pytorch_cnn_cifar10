# %% [markdown]
# ### Use CNN with PyTorch to learn CIFAR-10 (cuda)

# %%
import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Hyper parameters
num_epochs = 250
hidden_sizes = [512]
input_channels = 3
num_classes = 10
batch_size = 100
learning_rate = 0.001
lr_decay_epoch = 150

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Load CIFAR-10 dataset
# Can be downloaded by `torchvision.datasets`
#
# https://pytorch.org/docs/stable/torchvision/datasets.html

# %%
# CIFAR-10 dataset (32x32 colour images in 10 classes)
# https://www.cs.toronto.edu/~kriz/cifar.html
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = torchvision.datasets.CIFAR10(root='dataset/',
                                           train=True, 
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.CIFAR10(root='dataset/',
                                          train=False, 
                                          transform=transform,
                                          download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
plt.imshow(train_dataset.train_data[0])

# %%
print('Original train size:', train_dataset.train_data.shape)
print(len(train_dataset.train_labels))
print('Original test size:', test_dataset.test_data.shape)
print(len(test_dataset.test_labels))
# Out:
# Original train size: (50000, 32, 32, 3)
# 50000
# Original test size: (10000, 32, 32, 3)
# 10000

# %%
# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %% [markdown]
# ### See data dimensions and show images

# %%
sample_train_data = iter(train_loader)
images, labels = sample_train_data.next()

# %%
print('After DataLoader')
print('Train dimensions:', images.shape)
print(len(labels))
# Out:
# After DataLoader
# Train dimensions: torch.Size([100, 3, 32, 32])
# 100

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

fig = plt.figure(figsize = (15, 15))
def show_photo(img, i, lname):
    img = img / 2 + 0.5
    npimg = img.numpy()
    ax = fig.add_subplot(10, 1, i)
    ax.imshow(np.transpose(npimg, (1, 2, 0)))
    ax.axis('off')
    ax.set_title(label=lname, x=-0.2, y=0.3)

for label, lname in enumerate(classes):
    target_label = (labels == label)
    imgs = images[target_label][:6]   
    show_photo(torchvision.utils.make_grid(imgs), label + 1, lname)

# %% [markdown]
# ### Model vgg:
#
# Vgg16
#
#
# ```
# Dimensions:
# -> Input(32, 32)
# -> Conv (64, 32, 32)
# -> Conv (64, 32, 32)
# -> MaxPool (64, 16, 16)
#
# -> Conv (128, 16, 16)
# -> Conv (128, 16, 16)
# -> MaxPool (128, 8, 8)
#
# -> Conv (256, 8, 8)
# -> Conv (256, 8, 8)
# -> Conv (256, 8, 8)
# -> MaxPool (256, 4, 4)
#
# -> Conv (512, 4, 4)
# -> Conv (512, 4, 4)
# -> Conv (512, 4, 4)
# -> MaxPool (512, 2, 2)
#
# -> Conv (512, 2, 2)
# -> Conv (512, 2, 2)
# -> Conv (512, 2, 2)
# -> MaxPool (512, 1, 1)
#
# -> Fully Connected Layer(Logits (10, 1) -> Softmax) -> Labels
# ```

# %% [markdown]
# ### Build CNN model

# %%
class PytorchDeepConvNetVgg(nn.Module):
    def __init__(self, input_channels, num_classes=10):
        super(PytorchDeepConvNetVgg, self).__init__()

        # Layer 1: conv - relu - conv- relu - pool
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=input_channels, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))        
        
        # Layer 2: conv - relu - conv- relu - pool
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))

        # Layer 3: conv - relu - conv- relu - pool
        self.layer3 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))

        # Layer 4: conv - relu - conv- relu - pool
        self.layer4 = nn.Sequential(
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))

        # Layer 5: conv - relu - conv- relu - pool
        self.layer5 = nn.Sequential(
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5))


        # Fully Connected 1 (readout)
        # Affine - ReLU - Dropout - Affine - Dropout - Softmax
        self.layer6 = nn.Sequential(
            nn.Linear(512 * 1 * 1, hidden_sizes[0]),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden_sizes[0], num_classes))

        # Initialize all parameters using kaiming normalization
        self.init_weights_kaiming()
    
    def init_weights_kaiming(self):
        #Use kaiming normalization to initialize the parameters
        for layer in [self.layer1, self.layer2, self.layer3, self.layer4, self.layer5, self.layer6]:
            for m in layer:
                if type(m) == nn.Conv2d or type(m) == nn.Linear:
                    m.weight = nn.init.kaiming_normal_(m.weight)

    def forward(self, x):

        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        
        out = out.view(out.size(0), -1)
    
        # Linear function (readout)
        out = self.layer6(out)
        
        return out

# %%
model = PytorchDeepConvNetVgg(input_channels, num_classes).to(device)
# print(model)

# %%
criterion = nn.CrossEntropyLoss()

# %%
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay= 0.0005, momentum=0.9, nesterov=True)

# Use Adam as the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Learning rate decay schedule

# %%
exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=lr_decay_epoch, gamma=0.1)

# %% [markdown]
# ### Load pretrained model parameters

# %%
# model.load_state_dict(torch.load('model_vgg.ckpt'))

# %% [markdown]
# ### Train model

# %%
iter = 0
accuracies = []
for epoch in range(num_epochs):
    
    # Learning rate decay
    exp_lr_scheduler.step()

    # Print current learning rate
    if epoch % 25 == 0:
        print('learning rate:', optimizer.param_groups[0]['lr'])

    for i, (images, labels) in enumerate(train_loader):
        
        # Load images as Variable
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        
        # Clear gradients w.r.t parameters
        optimizer.zero_grad()
        
        # Forward pass to get output/logits
        outputs = model(images)
        
        # Calculate Loss: Softmax --> cross entropy loss
        loss = criterion(outputs, labels)
        
        # Getting gradients w.r.t paramters
        loss.backward()
        
        # Updating parameters
        optimizer.step()
        
        iter += 1 

        if iter % 500 == 0:
            correct = 0
            total = 0
            model.eval()
            with torch.no_grad():            
                for images, labels in test_loader:
                    images = Variable(images).to(device)
                    outputs = model(images)

                    _, predicted = torch.max(outputs.data, 1)

                    # Total numer of labels
                    total += labels.size(0)

                    correct += (predicted.to(device) == labels.to(device)).sum()

                accuracy = 100 * correct / total
                accuracies.append(accuracy)
        
            # Print Loss
            print('Iteration: {}. Loss: {}. Accuracy: {}'.format(iter, loss.data.item(), accuracy))
# Out:
# learning rate: 0.001
# Iteration: 500. Loss: 1.5580874681472778. Accuracy: 36
# Iteration: 1000. Loss: 1.6836506128311157. Accuracy: 41
# Iteration: 1500. Loss: 1.4519891738891602. Accuracy: 52
# Iteration: 2000. Loss: 0.8423556685447693. Accuracy: 65
# Iteration: 2500. Loss: 0.7688329815864563. Accuracy: 70
# Iteration: 3000. Loss: 0.7091527581214905. Accuracy: 76
# Iteration: 3500. Loss: 0.5343819260597229. Accuracy: 77
# Iteration: 4000. Loss: 0.511055588722229. Accuracy: 78
# Iteration: 4500. Loss: 0.38881924748420715. Accuracy: 79
# Iteration: 5000. Loss: 0.2992009222507477. Accuracy: 80
# Iteration: 5500. Loss: 0.4635956883430481. Accuracy: 80
# Iteration: 6000. Loss: 0.3647504150867462. Accuracy: 81
# Iteration: 6500. Loss: 0.2531948387622833. Accuracy: 81
# Iteration: 7000. Loss: 0.17601355910301208. Accuracy: 81
# Iteration: 7500. Loss: 0.14818698167800903. Accuracy: 81
# Iteration: 8000. Loss: 0.11052117496728897. Accuracy: 82
# Iteration: 8500. Loss: 0.1579228788614273. Accuracy: 81
# Iteration: 9000. Loss: 0.1531882882118225. Accuracy: 81
# Iteration: 9500. Loss: 0.12094061076641083. Accuracy: 81
# Iteration: 10000. Loss: 0.047391377389431. Accuracy: 82
# Iteration: 10500. Loss: 0.16148406267166138. Accuracy: 82
# Iteration: 11000. Loss: 0.06823203712701797. Accuracy: 83
# Iteration: 11500. Loss: 0.019110295921564102. Accuracy: 82
# Iteration: 12000. Loss: 0.11952928453683853. Accuracy: 81
# Iteration: 12500. Loss: 0.03576325997710228. Accuracy: 81
# learning rate: 0.001
# Iteration: 13000. Loss: 0.09585734456777573. Accuracy: 81
# Iteration: 13500. Loss: 0.0031857204157859087. Accuracy: 81
# Iteration: 14000. Loss: 0.009130436927080154. Accuracy: 82
# Iteration: 14500. Loss: 0.07027020305395126. Accuracy: 82
# Iteration: 15000. Loss: 0.03519890829920769. Accuracy: 82
# Iteration: 15500. Loss: 0.11918892711400986. Accuracy: 82
# Iteration: 16000. Loss: 0.08045818656682968. Accuracy: 83
# Iteration: 16500. Loss: 0.08310094475746155. Accuracy: 82
# Iteration: 17000. Loss: 0.004176297225058079. Accuracy: 82
# Iteration: 17500. Loss: 0.01834232732653618. Accuracy: 82
# Iteration: 18000. Loss: 0.004938037600368261. Accuracy: 82
# Iteration: 18500. Loss: 0.03454739227890968. Accuracy: 83
# Iteration: 19000. Loss: 0.011353615671396255. Accuracy: 82
# Iteration: 19500. Loss: 0.108530193567276. Accuracy: 82
# Iteration: 20000. Loss: 0.06645528227090836. Accuracy: 82
# Iteration: 20500. Loss: 0.05346103757619858. Accuracy: 82
# Iteration: 21000. Loss: 0.00328017002902925. Accuracy: 82
# Iteration: 21500. Loss: 0.11238160729408264. Accuracy: 82
# Iteration: 22000. Loss: 0.04143305867910385. Accuracy: 83
# Iteration: 22500. Loss: 0.03432498127222061. Accuracy: 82
# Iteration: 23000. Loss: 0.030139677226543427. Accuracy: 82
# Iteration: 23500. Loss: 0.05110088363289833. Accuracy: 83
# Iteration: 24000. Loss: 0.006420331075787544. Accuracy: 83
# Iteration: 24500. Loss: 0.05917949974536896. Accuracy: 83
# Iteration: 25000. Loss: 0.06366493552923203. Accuracy: 83
# learning rate: 0.001
# Iteration: 25500. Loss: 0.006047101225703955. Accuracy: 82
# Iteration: 26000. Loss: 0.0018418884137645364. Accuracy: 83
# Iteration: 26500. Loss: 0.007843677885830402. Accuracy: 83
# Iteration: 27000. Loss: 0.015897782519459724. Accuracy: 83
# Iteration: 27500. Loss: 0.024512281641364098. Accuracy: 83
# Iteration: 28000. Loss: 0.002638907404616475. Accuracy: 82
# Iteration: 28500. Loss: 0.013026532717049122. Accuracy: 83
# Iteration: 29000. Loss: 0.010775066912174225. Accuracy: 82
# Iteration: 29500. Loss: 0.011536133475601673. Accuracy: 83
# Iteration: 30000. Loss: 0.1540195196866989. Accuracy: 83
# Iteration: 30500. Loss: 0.09709260612726212. Accuracy: 82
# Iteration: 31000. Loss: 0.20823951065540314. Accuracy: 82
# Iteration: 31500. Loss: 0.021069912239909172. Accuracy: 83
# Iteration: 32000. Loss: 0.052780911326408386. Accuracy: 84
# Iteration: 32500. Loss: 0.028779111802577972. Accuracy: 83
# Iteration: 33000. Loss: 0.014476338401436806. Accuracy: 83
# Iteration: 33500. Loss: 0.002329234965145588. Accuracy: 83
# Iteration: 34000. Loss: 0.025218719616532326. Accuracy: 83
# Iteration: 34500. Loss: 0.0013050079578533769. Accuracy: 82
# Iteration: 35000. Loss: 0.0009141206974163651. Accuracy: 83
# Iteration: 35500. Loss: 0.1520012617111206. Accuracy: 83
# Iteration: 36000. Loss: 0.007748360745608807. Accuracy: 83
# Iteration: 36500. Loss: 0.11132091283798218. Accuracy: 81
# Iteration: 37000. Loss: 0.005521781276911497. Accuracy: 83
# Iteration: 37500. Loss: 0.004938114900141954. Accuracy: 83
# learning rate: 0.001
# Iteration: 38000. Loss: 0.04804951697587967. Accuracy: 83
# Iteration: 38500. Loss: 0.0009576058364473283. Accuracy: 83
# Iteration: 39000. Loss: 0.008642826229333878. Accuracy: 83
# Iteration: 39500. Loss: 0.006182841025292873. Accuracy: 83
# Iteration: 40000. Loss: 0.04607628658413887. Accuracy: 82
# Iteration: 40500. Loss: 0.024227656424045563. Accuracy: 83
# Iteration: 41000. Loss: 0.0005031490582041442. Accuracy: 83
# Iteration: 41500. Loss: 0.016358569264411926. Accuracy: 83
# Iteration: 42000. Loss: 0.011290627531707287. Accuracy: 83
# Iteration: 42500. Loss: 0.01126974355429411. Accuracy: 84
# Iteration: 43000. Loss: 0.021456614136695862. Accuracy: 82
# Iteration: 43500. Loss: 0.001626589335501194. Accuracy: 83
# Iteration: 44000. Loss: 0.0011291432892903686. Accuracy: 83
# Iteration: 44500. Loss: 0.053450170904397964. Accuracy: 83
# Iteration: 45000. Loss: 0.014104431495070457. Accuracy: 83
# Iteration: 45500. Loss: 0.001298278570175171. Accuracy: 84
# Iteration: 46000. Loss: 0.01944645494222641. Accuracy: 83
# Iteration: 46500. Loss: 0.048892345279455185. Accuracy: 82
# Iteration: 47000. Loss: 0.0012417042162269354. Accuracy: 83
# Iteration: 47500. Loss: 0.06066904962062836. Accuracy: 82
# Iteration: 48000. Loss: 0.017460795119404793. Accuracy: 84
# Iteration: 48500. Loss: 0.008356703445315361. Accuracy: 83
# Iteration: 49000. Loss: 0.004486491903662682. Accuracy: 83
# Iteration: 49500. Loss: 0.007399114314466715. Accuracy: 84
# Iteration: 50000. Loss: 0.006333945784717798. Accuracy: 83
# learning rate: 0.001
# Iteration: 50500. Loss: 0.0004184246063232422. Accuracy: 84
# Iteration: 51000. Loss: 0.03444882109761238. Accuracy: 83
# Iteration: 51500. Loss: 0.06052077189087868. Accuracy: 83
# Iteration: 52000. Loss: 0.0009928179206326604. Accuracy: 83
# Iteration: 52500. Loss: 0.0038055514451116323. Accuracy: 84
# Iteration: 53000. Loss: 0.002801064169034362. Accuracy: 83
# Iteration: 53500. Loss: 0.00026458740467205644. Accuracy: 83
# Iteration: 54000. Loss: 0.010597684420645237. Accuracy: 83
# Iteration: 54500. Loss: 0.0983738824725151. Accuracy: 84
# Iteration: 55000. Loss: 0.00019303560839034617. Accuracy: 84
# Iteration: 55500. Loss: 0.10468151420354843. Accuracy: 83
# Iteration: 56000. Loss: 0.04281463474035263. Accuracy: 83
# Iteration: 56500. Loss: 0.003826696891337633. Accuracy: 83
# Iteration: 57000. Loss: 0.0009207105613313615. Accuracy: 83
# Iteration: 57500. Loss: 0.0005620026495307684. Accuracy: 83
# Iteration: 58000. Loss: 0.05232849717140198. Accuracy: 82
# Iteration: 58500. Loss: 0.008143123239278793. Accuracy: 83
# Iteration: 59000. Loss: 0.016718387603759766. Accuracy: 84
# Iteration: 59500. Loss: 0.04072459042072296. Accuracy: 83
# Iteration: 60000. Loss: 0.0021996235009282827. Accuracy: 83
# Iteration: 60500. Loss: 0.03064119815826416. Accuracy: 83
# Iteration: 61000. Loss: 0.007156972773373127. Accuracy: 84
# Iteration: 61500. Loss: 0.014892981387674809. Accuracy: 83
# Iteration: 62000. Loss: 0.032462168484926224. Accuracy: 84
# Iteration: 62500. Loss: 0.005484636873006821. Accuracy: 83
# learning rate: 0.001
# Iteration: 63000. Loss: 0.004469410050660372. Accuracy: 82
# Iteration: 63500. Loss: 0.0003101062902715057. Accuracy: 83
# Iteration: 64000. Loss: 0.050003767013549805. Accuracy: 82
# Iteration: 64500. Loss: 0.00685020349919796. Accuracy: 84
# Iteration: 65000. Loss: 0.0017389821587130427. Accuracy: 84
# Iteration: 65500. Loss: 0.00016007543308660388. Accuracy: 83
# Iteration: 66000. Loss: 0.0009443759918212891. Accuracy: 83
# Iteration: 66500. Loss: 0.0015712546883150935. Accuracy: 83
# Iteration: 67000. Loss: 0.005937403533607721. Accuracy: 83
# Iteration: 67500. Loss: 0.00017035365453921258. Accuracy: 84
# Iteration: 68000. Loss: 7.136106432881206e-05. Accuracy: 84
# Iteration: 68500. Loss: 0.00157570478040725. Accuracy: 83
# Iteration: 69000. Loss: 0.03072003833949566. Accuracy: 83
# Iteration: 69500. Loss: 0.0001408076350344345. Accuracy: 83
# Iteration: 70000. Loss: 0.023274356499314308. Accuracy: 83
# Iteration: 70500. Loss: 0.019405245780944824. Accuracy: 83
# Iteration: 71000. Loss: 0.06291788071393967. Accuracy: 83
# Iteration: 71500. Loss: 0.010892897844314575. Accuracy: 83
# Iteration: 72000. Loss: 0.00046991585986688733. Accuracy: 84
# Iteration: 72500. Loss: 0.0027325102128088474. Accuracy: 84
# Iteration: 73000. Loss: 0.043500903993844986. Accuracy: 83
# Iteration: 73500. Loss: 0.04209652543067932. Accuracy: 83
# Iteration: 74000. Loss: 0.0031830715015530586. Accuracy: 83
# Iteration: 74500. Loss: 0.0006430256180465221. Accuracy: 84
# Iteration: 75000. Loss: 0.00022830248053651303. Accuracy: 83
# learning rate: 0.0001
# Iteration: 75500. Loss: 6.797671085223556e-05. Accuracy: 84
# Iteration: 76000. Loss: 1.643419273023028e-05. Accuracy: 84
# Iteration: 76500. Loss: 1.2731552487821318e-05. Accuracy: 84
# Iteration: 77000. Loss: 2.362966552027501e-05. Accuracy: 84
# Iteration: 77500. Loss: 4.524707765085623e-05. Accuracy: 84
# Iteration: 78000. Loss: 3.1533239962300286e-05. Accuracy: 84
# Iteration: 78500. Loss: 5.7077409110206645e-06. Accuracy: 84
# Iteration: 79000. Loss: 5.416869953478454e-06. Accuracy: 84
# Iteration: 79500. Loss: 1.1050701687054243e-06. Accuracy: 84
# Iteration: 80000. Loss: 3.194809039541724e-07. Accuracy: 84
# Iteration: 80500. Loss: 9.89437126008852e-07. Accuracy: 84
# Iteration: 81000. Loss: 5.865097136847908e-07. Accuracy: 84
# Iteration: 81500. Loss: 3.879070391121786e-06. Accuracy: 84
# Iteration: 82000. Loss: 8.249282927863533e-07. Accuracy: 84
# Iteration: 82500. Loss: 3.814697180359872e-08. Accuracy: 84
# Iteration: 83000. Loss: 8.82148754044465e-08. Accuracy: 84
# Iteration: 83500. Loss: 2.3841858265427618e-08. Accuracy: 84
# Iteration: 84000. Loss: 3.5047531810050714e-07. Accuracy: 84
# Iteration: 84500. Loss: 0.0. Accuracy: 84
# Iteration: 85000. Loss: 5.2452087118126656e-08. Accuracy: 84
# Iteration: 85500. Loss: 1.0251999071897444e-07. Accuracy: 84
# Iteration: 86000. Loss: 0.0. Accuracy: 84
# Iteration: 86500. Loss: 0.0. Accuracy: 84
# Iteration: 87000. Loss: 0.0. Accuracy: 84
# Iteration: 87500. Loss: 2.5033950024067053e-08. Accuracy: 84
# learning rate: 0.0001
# Iteration: 88000. Loss: 0.0. Accuracy: 84
# Iteration: 88500. Loss: 0.0. Accuracy: 84
# Iteration: 89000. Loss: 9.53674295089968e-09. Accuracy: 84
# Iteration: 89500. Loss: 0.0. Accuracy: 84
# Iteration: 90000. Loss: 0.0. Accuracy: 84
# Iteration: 90500. Loss: 0.0. Accuracy: 84
# Iteration: 91000. Loss: 0.0. Accuracy: 84
# Iteration: 91500. Loss: 1.19209286886246e-09. Accuracy: 84
# Iteration: 92000. Loss: 5.9604645663569045e-09. Accuracy: 84
# Iteration: 92500. Loss: 0.0. Accuracy: 84
# Iteration: 93000. Loss: 0.0. Accuracy: 84
# Iteration: 93500. Loss: 0.0. Accuracy: 84
# Iteration: 94000. Loss: 0.0. Accuracy: 84
# Iteration: 94500. Loss: 0.0. Accuracy: 84
# Iteration: 95000. Loss: 0.0. Accuracy: 84
# Iteration: 95500. Loss: 0.0. Accuracy: 84
# Iteration: 96000. Loss: 0.0. Accuracy: 84
# Iteration: 96500. Loss: 0.0. Accuracy: 84
# Iteration: 97000. Loss: 0.0. Accuracy: 84
# Iteration: 97500. Loss: 0.0. Accuracy: 84
# Iteration: 98000. Loss: 0.0. Accuracy: 84
# Iteration: 98500. Loss: 0.0. Accuracy: 84
# Iteration: 99000. Loss: 0.0. Accuracy: 84
# Iteration: 99500. Loss: 0.0. Accuracy: 84
# Iteration: 100000. Loss: 0.0. Accuracy: 84
# learning rate: 0.0001
# Iteration: 100500. Loss: 0.0. Accuracy: 84
# Iteration: 101000. Loss: 0.0. Accuracy: 84
# Iteration: 101500. Loss: 0.0. Accuracy: 84
# Iteration: 102000. Loss: 0.0. Accuracy: 84
# Iteration: 102500. Loss: 0.0. Accuracy: 84
# Iteration: 103000. Loss: 0.0. Accuracy: 84
# Iteration: 103500. Loss: 0.0. Accuracy: 84
# Iteration: 104000. Loss: 0.0. Accuracy: 84
# Iteration: 104500. Loss: 0.0. Accuracy: 84
# Iteration: 105000. Loss: 0.0. Accuracy: 84
# Iteration: 105500. Loss: 0.0. Accuracy: 84
# Iteration: 106000. Loss: 0.0. Accuracy: 84
# Iteration: 106500. Loss: 0.0. Accuracy: 84
# Iteration: 107000. Loss: 0.0. Accuracy: 84
# Iteration: 107500. Loss: 0.0. Accuracy: 84
# Iteration: 108000. Loss: 0.0. Accuracy: 84
# Iteration: 108500. Loss: 0.0. Accuracy: 84
# Iteration: 109000. Loss: 0.0. Accuracy: 84
# Iteration: 109500. Loss: 0.0. Accuracy: 84
# Iteration: 110000. Loss: 0.0. Accuracy: 84
# Iteration: 110500. Loss: 0.0. Accuracy: 84
# Iteration: 111000. Loss: 0.0. Accuracy: 84
# Iteration: 111500. Loss: 0.0. Accuracy: 84
# Iteration: 112000. Loss: 0.0. Accuracy: 84
# Iteration: 112500. Loss: 0.0. Accuracy: 84
# learning rate: 0.0001
# Iteration: 113000. Loss: 0.0. Accuracy: 84
# Iteration: 113500. Loss: 0.0. Accuracy: 84
# Iteration: 114000. Loss: 0.0. Accuracy: 84
# Iteration: 114500. Loss: 0.0. Accuracy: 84
# Iteration: 115000. Loss: 0.0. Accuracy: 84
# Iteration: 115500. Loss: 0.0. Accuracy: 84
# Iteration: 116000. Loss: 0.0. Accuracy: 84
# Iteration: 116500. Loss: 0.0. Accuracy: 84
# Iteration: 117000. Loss: 0.0. Accuracy: 84
# Iteration: 117500. Loss: 0.0. Accuracy: 84
# Iteration: 118000. Loss: 0.0. Accuracy: 84
# Iteration: 118500. Loss: 0.0. Accuracy: 84
# Iteration: 119000. Loss: 0.0. Accuracy: 84
# Iteration: 119500. Loss: 0.0. Accuracy: 84
# Iteration: 120000. Loss: 0.0. Accuracy: 84
# Iteration: 120500. Loss: 0.0. Accuracy: 84
# Iteration: 121000. Loss: 0.0. Accuracy: 84
# Iteration: 121500. Loss: 0.0. Accuracy: 84
# Iteration: 122000. Loss: 0.0. Accuracy: 84
# Iteration: 122500. Loss: 0.0. Accuracy: 84
# Iteration: 123000. Loss: 0.0. Accuracy: 84
# Iteration: 123500. Loss: 0.0. Accuracy: 84
# Iteration: 124000. Loss: 0.0. Accuracy: 84
# Iteration: 124500. Loss: 0.0. Accuracy: 84
# Iteration: 125000. Loss: 0.0. Accuracy: 84

# %%
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Test Accuracy of the model on the 10000 test images: 84.64 %

# %%
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in train_loader:
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the 50000 train images: {} %'.format(100 * correct / total))
# Out:
# Test Accuracy of the model on the 50000 train images: 100.0 %

# %% [markdown]
# ### Test memo:
#
#
# |dataset size(train/test)|#epoch|      model  |  optimizer | parameters |lr| accuracy(test/train)  |
# |-----------------------|-------|--------------|------------|------------|--|------------|
# |50000/10000|25|(conv - relu - conv- relu - pool)x2, Linearx1 |torch.optim.Adam|Kaiming He|0.001| 69.43%/ 88.28%|
# |50000/10000|25|(conv - relu - conv- relu - pool)x3, linear-relu-dropout-linear-dropout |torch.optim.Adam|Kaiming He|0.001| 70.83%/ 96.01%|
# |50000/10000|25|vgg16 |torch.optim.Adam|Kaiming He|0.001| 81.01%/  97.64%|
# |50000/10000|50|vgg16 |torch.optim.Adam|Kaiming He|0.001| 83.66%/  99.74%|
# |50000/10000|100|vgg16 |torch.optim.Adam|Kaiming He|0.001->(50epoch)0.0001|  83.71%/  100.0%|
# |50000/10000|250|vgg16 |torch.optim.Adam|Kaiming He|0.001->(150epoch)0.0001|  84.64%/  100.0%|

# %%
# Save the model checkpoint
torch.save(model.state_dict(), 'model_vgg_250.ckpt')

# %%
# Added dropout layer refers to http://torch.ch/blog/2015/07/30/cifar.html
