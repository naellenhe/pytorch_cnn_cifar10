# %% [markdown]
# ### Use CNN with PyTorch to learn CIFAR-10 (cuda)

# %%
import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Hyper parameters
num_epochs = 300
hidden_sizes = [512]
input_channels = 3
num_classes = 10
batch_size = 100
learning_rate = 0.001

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Load CIFAR-10 dataset
# Can be downloaded by `torchvision.datasets`
#
# https://pytorch.org/docs/stable/torchvision/datasets.html

# %%
# CIFAR-10 dataset (32x32 colour images in 10 classes)
# https://www.cs.toronto.edu/~kriz/cifar.html
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = torchvision.datasets.CIFAR10(root='dataset/',
                                           train=True, 
                                           transform=transform,
                                           download=True)

test_dataset = torchvision.datasets.CIFAR10(root='dataset/',
                                          train=False, 
                                          transform=transform,
                                          download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
plt.imshow(train_dataset.train_data[0])

# %%
print('Original train size:', train_dataset.train_data.shape)
print(len(train_dataset.train_labels))
print('Original test size:', test_dataset.test_data.shape)
print(len(test_dataset.test_labels))
# Out:
# Original train size: (50000, 32, 32, 3)
# 50000
# Original test size: (10000, 32, 32, 3)
# 10000

# %%
# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %% [markdown]
# ### See data dimensions and show images

# %%
sample_train_data = iter(train_loader)
images, labels = sample_train_data.next()

# %%
print('After DataLoader')
print('Train dimensions:', images.shape)
print(len(labels))
# Out:
# After DataLoader
# Train dimensions: torch.Size([100, 3, 32, 32])
# 100

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

fig = plt.figure(figsize = (15, 15))
def show_photo(img, i, lname):
    img = img / 2 + 0.5
    npimg = img.numpy()
    ax = fig.add_subplot(10, 1, i)
    ax.imshow(np.transpose(npimg, (1, 2, 0)))
    ax.axis('off')
    ax.set_title(label=lname, x=-0.2, y=0.3)

for label, lname in enumerate(classes):
    target_label = (labels == label)
    imgs = images[target_label][:6]   
    show_photo(torchvision.utils.make_grid(imgs), label + 1, lname)

# %% [markdown]
# ### Model vgg:
#
# Vgg16
#
#
# ```
# Dimensions:
# -> Input(32, 32)
# -> Conv (64, 32, 32)
# -> Conv (64, 32, 32)
# -> MaxPool (64, 16, 16)
#
# -> Conv (128, 16, 16)
# -> Conv (128, 16, 16)
# -> MaxPool (128, 8, 8)
#
# -> Conv (256, 8, 8)
# -> Conv (256, 8, 8)
# -> Conv (256, 8, 8)
# -> MaxPool (256, 4, 4)
#
# -> Conv (512, 4, 4)
# -> Conv (512, 4, 4)
# -> Conv (512, 4, 4)
# -> MaxPool (512, 2, 2)
#
# -> Conv (512, 2, 2)
# -> Conv (512, 2, 2)
# -> Conv (512, 2, 2)
# -> MaxPool (512, 1, 1)
#
# -> Fully Connected Layer(Logits (10, 1) -> Softmax) -> Labels
# ```

# %% [markdown]
# ### Build CNN model

# %%
class PytorchDeepConvNetVgg(nn.Module):
    def __init__(self, input_channels, num_classes=10):
        super(PytorchDeepConvNetVgg, self).__init__()

        # Layer 1: conv - relu - conv- relu - pool
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=input_channels, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))        
        
        # Layer 2: conv - relu - conv- relu - pool
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))

        # Layer 3: conv - relu - conv- relu - pool
        self.layer3 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))

        # Layer 4: conv - relu - conv- relu - pool
        self.layer4 = nn.Sequential(
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))

        # Layer 5: conv - relu - conv- relu - pool
        self.layer5 = nn.Sequential(
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5))


        # Fully Connected 1 (readout)
        # Affine - ReLU - Dropout - Affine - Dropout - Softmax
        self.layer6 = nn.Sequential(
            nn.Linear(512 * 1 * 1, hidden_sizes[0]),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(hidden_sizes[0], num_classes))

        # Initialize all parameters using kaiming normalization
        self.init_weights_kaiming()
    
    def init_weights_kaiming(self):
        #Use kaiming normalization to initialize the parameters
        for layer in [self.layer1, self.layer2, self.layer3, self.layer4, self.layer5, self.layer6]:
            for m in layer:
                if type(m) == nn.Conv2d or type(m) == nn.Linear:
                    m.weight = nn.init.kaiming_normal_(m.weight)

    def forward(self, x):

        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        
        out = out.view(out.size(0), -1)
    
        # Linear function (readout)
        out = self.layer6(out)
        
        return out

# %%
model = PytorchDeepConvNetVgg(input_channels, num_classes).to(device)
# print(model)

# %%
criterion = nn.CrossEntropyLoss()

# %%
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay= 0.0005, momentum=0.9, nesterov=True)

# Use Adam as the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Learning rate decay schedule

# %%
exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=150, gamma=0.1)

# %% [markdown]
# ### Load pretrained model parameters

# %%
# model.load_state_dict(torch.load('model_vgg.ckpt'))

# %% [markdown]
# ### Train model

# %%
iter = 0
accuracies = []
for epoch in range(num_epochs):
    
    # Learning rate decay
    exp_lr_scheduler.step()

    # Print current learning rate
    if epoch % 25 == 0:
        print('learning rate:', optimizer.param_groups[0]['lr'])

    for i, (images, labels) in enumerate(train_loader):
        
        # Load images as Variable
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        
        # Clear gradients w.r.t parameters
        optimizer.zero_grad()
        
        # Forward pass to get output/logits
        outputs = model(images)
        
        # Calculate Loss: Softmax --> cross entropy loss
        loss = criterion(outputs, labels)
        
        # Getting gradients w.r.t paramters
        loss.backward()
        
        # Updating parameters
        optimizer.step()
        
        iter += 1 

        if iter % 500 == 0:
            correct = 0
            total = 0
            model.eval()
            with torch.no_grad():            
                for images, labels in test_loader:
                    images = Variable(images).to(device)
                    outputs = model(images)

                    _, predicted = torch.max(outputs.data, 1)

                    # Total numer of labels
                    total += labels.size(0)

                    correct += (predicted.to(device) == labels.to(device)).sum()

                accuracy = 100 * correct / total
                accuracies.append(accuracy)
        
            # Print Loss
            print('Iteration: {}. Loss: {}. Accuracy: {}'.format(iter, loss.data.item(), accuracy))
# Out:
# learning rate: 0.001
# Iteration: 500. Loss: 1.5968791246414185. Accuracy: 29
# Iteration: 1000. Loss: 1.0907267332077026. Accuracy: 52
# Iteration: 1500. Loss: 0.9203737378120422. Accuracy: 64
# Iteration: 2000. Loss: 0.8311523199081421. Accuracy: 71
# Iteration: 2500. Loss: 0.6591851115226746. Accuracy: 75
# Iteration: 3000. Loss: 0.619041383266449. Accuracy: 77
# Iteration: 3500. Loss: 0.3556014895439148. Accuracy: 79
# Iteration: 4000. Loss: 0.30365246534347534. Accuracy: 79
# Iteration: 4500. Loss: 0.29499512910842896. Accuracy: 80
# Iteration: 5000. Loss: 0.4414757788181305. Accuracy: 80
# Iteration: 5500. Loss: 0.20606884360313416. Accuracy: 81
# Iteration: 6000. Loss: 0.20232842862606049. Accuracy: 81
# Iteration: 6500. Loss: 0.13872148096561432. Accuracy: 81
# Iteration: 7000. Loss: 0.10061372816562653. Accuracy: 81
# Iteration: 7500. Loss: 0.08932965993881226. Accuracy: 80
# Iteration: 8000. Loss: 0.1693299412727356. Accuracy: 80
# Iteration: 8500. Loss: 0.1153867170214653. Accuracy: 81
# Iteration: 9000. Loss: 0.06318014115095139. Accuracy: 82
# Iteration: 9500. Loss: 0.0788063257932663. Accuracy: 81
# Iteration: 10000. Loss: 0.05898852273821831. Accuracy: 81
# Iteration: 10500. Loss: 0.03701655566692352. Accuracy: 81
# Iteration: 11000. Loss: 0.03346893936395645. Accuracy: 82
# Iteration: 11500. Loss: 0.06799721717834473. Accuracy: 81
# Iteration: 12000. Loss: 0.09182050079107285. Accuracy: 81
# Iteration: 12500. Loss: 0.02003384381532669. Accuracy: 82
# learning rate: 0.001
# Iteration: 13000. Loss: 0.020684801042079926. Accuracy: 81
# Iteration: 13500. Loss: 0.025054102763533592. Accuracy: 82
# Iteration: 14000. Loss: 0.28462472558021545. Accuracy: 81
# Iteration: 14500. Loss: 0.08346711844205856. Accuracy: 81
# Iteration: 15000. Loss: 0.0016777085838839412. Accuracy: 82
# Iteration: 15500. Loss: 0.10458824038505554. Accuracy: 81
# Iteration: 16000. Loss: 0.08315085619688034. Accuracy: 82
# Iteration: 16500. Loss: 0.0725833997130394. Accuracy: 83
# Iteration: 17000. Loss: 0.00954175740480423. Accuracy: 82
# Iteration: 17500. Loss: 0.09797358512878418. Accuracy: 82
# Iteration: 18000. Loss: 0.03618389368057251. Accuracy: 82
# Iteration: 18500. Loss: 0.0935240238904953. Accuracy: 81
# Iteration: 19000. Loss: 0.050108376890420914. Accuracy: 80
# Iteration: 19500. Loss: 0.002450690371915698. Accuracy: 82
# Iteration: 20000. Loss: 0.015549316070973873. Accuracy: 81
# Iteration: 20500. Loss: 0.06404303759336472. Accuracy: 82
# Iteration: 21000. Loss: 0.03205277770757675. Accuracy: 82
# Iteration: 21500. Loss: 0.0737883448600769. Accuracy: 82
# Iteration: 22000. Loss: 0.10985103249549866. Accuracy: 82
# Iteration: 22500. Loss: 0.04638035222887993. Accuracy: 82
# Iteration: 23000. Loss: 0.006592101883143187. Accuracy: 82
# Iteration: 23500. Loss: 0.0013155459892004728. Accuracy: 83
# Iteration: 24000. Loss: 0.0743224173784256. Accuracy: 82
# Iteration: 24500. Loss: 0.08474750816822052. Accuracy: 82
# Iteration: 25000. Loss: 0.057837504893541336. Accuracy: 82
# learning rate: 0.001
# Iteration: 25500. Loss: 0.015154211781919003. Accuracy: 82
# Iteration: 26000. Loss: 0.051329225301742554. Accuracy: 81
# Iteration: 26500. Loss: 0.010927891358733177. Accuracy: 82
# Iteration: 27000. Loss: 0.01848035864531994. Accuracy: 83
# Iteration: 27500. Loss: 0.0033519004937261343. Accuracy: 83
# Iteration: 28000. Loss: 0.03884424641728401. Accuracy: 83
# Iteration: 28500. Loss: 0.011835812591016293. Accuracy: 83
# Iteration: 29000. Loss: 0.03542248159646988. Accuracy: 82
# Iteration: 29500. Loss: 0.03272285684943199. Accuracy: 82
# Iteration: 30000. Loss: 0.006625876296311617. Accuracy: 82
# Iteration: 30500. Loss: 0.0026633262168616056. Accuracy: 83
# Iteration: 31000. Loss: 0.02711087465286255. Accuracy: 82
# Iteration: 31500. Loss: 0.06159399077296257. Accuracy: 82
# Iteration: 32000. Loss: 0.026025013998150826. Accuracy: 82
# Iteration: 32500. Loss: 0.03588642179965973. Accuracy: 82
# Iteration: 33000. Loss: 0.0014649081276729703. Accuracy: 82
# Iteration: 33500. Loss: 0.015342805534601212. Accuracy: 83
# Iteration: 34000. Loss: 0.1273772269487381. Accuracy: 83
# Iteration: 34500. Loss: 0.04873865470290184. Accuracy: 83
# Iteration: 35000. Loss: 0.00401601567864418. Accuracy: 82
# Iteration: 35500. Loss: 0.04769737645983696. Accuracy: 82
# Iteration: 36000. Loss: 0.0038111996836960316. Accuracy: 83
# Iteration: 36500. Loss: 0.01253905612975359. Accuracy: 82
# Iteration: 37000. Loss: 0.04259556159377098. Accuracy: 82
# Iteration: 37500. Loss: 0.002645113505423069. Accuracy: 83
# learning rate: 0.001
# Iteration: 38000. Loss: 0.01247074268758297. Accuracy: 82
# Iteration: 38500. Loss: 0.0021947240456938744. Accuracy: 83
# Iteration: 39000. Loss: 0.005805691704154015. Accuracy: 83
# Iteration: 39500. Loss: 0.010566525161266327. Accuracy: 83
# Iteration: 40000. Loss: 0.002259154338389635. Accuracy: 83
# Iteration: 40500. Loss: 0.00631837360560894. Accuracy: 82
# Iteration: 41000. Loss: 0.009706301614642143. Accuracy: 83
# Iteration: 41500. Loss: 0.14698663353919983. Accuracy: 83
# Iteration: 42000. Loss: 0.00347869168035686. Accuracy: 83
# Iteration: 42500. Loss: 0.05480429157614708. Accuracy: 82
# Iteration: 43000. Loss: 0.0021529316436499357. Accuracy: 82
# Iteration: 43500. Loss: 0.00138691661413759. Accuracy: 83
# Iteration: 44000. Loss: 0.3359029293060303. Accuracy: 80
# Iteration: 44500. Loss: 0.013451728038489819. Accuracy: 83
# Iteration: 45000. Loss: 0.010989688336849213. Accuracy: 83
# Iteration: 45500. Loss: 0.03473531827330589. Accuracy: 83
# Iteration: 46000. Loss: 0.07520860433578491. Accuracy: 83
# Iteration: 46500. Loss: 0.0003013944660779089. Accuracy: 83
# Iteration: 47000. Loss: 0.007056117057800293. Accuracy: 83
# Iteration: 47500. Loss: 0.001854472211562097. Accuracy: 82
# Iteration: 48000. Loss: 0.08978775143623352. Accuracy: 82
# Iteration: 48500. Loss: 0.0003503775515127927. Accuracy: 83
# Iteration: 49000. Loss: 0.01588902808725834. Accuracy: 83
# Iteration: 49500. Loss: 0.04961047321557999. Accuracy: 83
# Iteration: 50000. Loss: 0.00383851770311594. Accuracy: 83
# learning rate: 0.001
# Iteration: 50500. Loss: 0.0170286875218153. Accuracy: 83
# Iteration: 51000. Loss: 0.007294448092579842. Accuracy: 82
# Iteration: 51500. Loss: 0.0036905037704855204. Accuracy: 83
# Iteration: 52000. Loss: 0.00267512327991426. Accuracy: 83
# Iteration: 52500. Loss: 0.15569108724594116. Accuracy: 83
# Iteration: 53000. Loss: 0.013809209689497948. Accuracy: 83
# Iteration: 53500. Loss: 0.0004836308944504708. Accuracy: 82
# Iteration: 54000. Loss: 0.009412247687578201. Accuracy: 83
# Iteration: 54500. Loss: 0.00016641616821289062. Accuracy: 84
# Iteration: 55000. Loss: 0.0027557313442230225. Accuracy: 83
# Iteration: 55500. Loss: 0.005075284279882908. Accuracy: 82
# Iteration: 56000. Loss: 0.04527280852198601. Accuracy: 83
# Iteration: 56500. Loss: 0.03091255947947502. Accuracy: 83
# Iteration: 57000. Loss: 0.0035286631900817156. Accuracy: 83
# Iteration: 57500. Loss: 0.02504543587565422. Accuracy: 82
# Iteration: 58000. Loss: 0.007916185073554516. Accuracy: 82
# Iteration: 58500. Loss: 0.013346957042813301. Accuracy: 83
# Iteration: 59000. Loss: 0.004026402719318867. Accuracy: 84
# Iteration: 59500. Loss: 0.005504433996975422. Accuracy: 84
# Iteration: 60000. Loss: 0.0010990273440256715. Accuracy: 83
# Iteration: 60500. Loss: 0.003968530800193548. Accuracy: 83
# Iteration: 61000. Loss: 0.00036071299109607935. Accuracy: 84
# Iteration: 61500. Loss: 0.11741650849580765. Accuracy: 83
# Iteration: 62000. Loss: 0.0041806637309491634. Accuracy: 83
# Iteration: 62500. Loss: 3.2742023904575035e-05. Accuracy: 84
# learning rate: 0.001
# Iteration: 63000. Loss: 0.0043930113315582275. Accuracy: 82
# Iteration: 63500. Loss: 0.02271607704460621. Accuracy: 82
# Iteration: 64000. Loss: 0.000773284409660846. Accuracy: 84
# Iteration: 64500. Loss: 0.03086359240114689. Accuracy: 83
# Iteration: 65000. Loss: 0.002238211687654257. Accuracy: 83
# Iteration: 65500. Loss: 0.0016366910422220826. Accuracy: 83
# Iteration: 66000. Loss: 0.06225580349564552. Accuracy: 83
# Iteration: 66500. Loss: 0.02002090960741043. Accuracy: 84
# Iteration: 67000. Loss: 0.0259548332542181. Accuracy: 82
# Iteration: 67500. Loss: 0.01105524878948927. Accuracy: 83
# Iteration: 68000. Loss: 0.0026428138371556997. Accuracy: 82
# Iteration: 68500. Loss: 0.015576548874378204. Accuracy: 83
# Iteration: 69000. Loss: 0.010088379494845867. Accuracy: 83
# Iteration: 69500. Loss: 0.0012955927522853017. Accuracy: 83
# Iteration: 70000. Loss: 0.001989173935726285. Accuracy: 83
# Iteration: 70500. Loss: 0.01795896328985691. Accuracy: 83
# Iteration: 71000. Loss: 0.004080633632838726. Accuracy: 84
# Iteration: 71500. Loss: 0.005037997849285603. Accuracy: 83
# Iteration: 72000. Loss: 0.000718884461093694. Accuracy: 84
# Iteration: 72500. Loss: 0.007474809885025024. Accuracy: 84
# Iteration: 73000. Loss: 0.023856276646256447. Accuracy: 83
# Iteration: 73500. Loss: 0.023523472249507904. Accuracy: 82
# Iteration: 74000. Loss: 0.0011439621448516846. Accuracy: 84
# Iteration: 74500. Loss: 0.003987358417361975. Accuracy: 83
# Iteration: 75000. Loss: 0.00015447914483956993. Accuracy: 83
# learning rate: 0.0001
# Iteration: 75500. Loss: 0.0004421621561050415. Accuracy: 84
# Iteration: 76000. Loss: 4.863262074650265e-05. Accuracy: 84
# Iteration: 76500. Loss: 0.00010532617307035252. Accuracy: 84
# Iteration: 77000. Loss: 2.9705763154197484e-05. Accuracy: 84
# Iteration: 77500. Loss: 6.602406301681185e-06. Accuracy: 84
# Iteration: 78000. Loss: 1.1472701771708671e-05. Accuracy: 84
# Iteration: 78500. Loss: 9.298324584960938e-06. Accuracy: 84
# Iteration: 79000. Loss: 7.534027304245683e-07. Accuracy: 84
# Iteration: 79500. Loss: 2.8610228852699038e-08. Accuracy: 84
# Iteration: 80000. Loss: 1.8596648487800849e-07. Accuracy: 84
# Iteration: 80500. Loss: 7.426738761751039e-07. Accuracy: 84
# Iteration: 81000. Loss: 5.2452087118126656e-08. Accuracy: 84
# Iteration: 81500. Loss: 2.121925319897855e-07. Accuracy: 84
# Iteration: 82000. Loss: 3.814697180359872e-08. Accuracy: 84
# Iteration: 82500. Loss: 1.3589858838258806e-07. Accuracy: 84
# Iteration: 83000. Loss: 3.7193296975601697e-07. Accuracy: 84
# Iteration: 83500. Loss: 1.1205673189351728e-07. Accuracy: 84
# Iteration: 84000. Loss: 0.0. Accuracy: 84
# Iteration: 84500. Loss: 1.4305115314527939e-07. Accuracy: 84
# Iteration: 85000. Loss: 2.1457672971791908e-08. Accuracy: 84
# Iteration: 85500. Loss: 4.76837147544984e-09. Accuracy: 84
# Iteration: 86000. Loss: 0.0. Accuracy: 84
# Iteration: 86500. Loss: 0.0. Accuracy: 84
# Iteration: 87000. Loss: 0.0. Accuracy: 84
# Iteration: 87500. Loss: 0.0. Accuracy: 84
# learning rate: 0.0001
# Iteration: 88000. Loss: 5.9604645663569045e-09. Accuracy: 84
# Iteration: 88500. Loss: 0.0. Accuracy: 84
# Iteration: 89000. Loss: 0.0. Accuracy: 84
# Iteration: 89500. Loss: 0.0. Accuracy: 84
# Iteration: 90000. Loss: 0.0. Accuracy: 84
# Iteration: 90500. Loss: 0.0. Accuracy: 84
# Iteration: 91000. Loss: 0.0. Accuracy: 84
# Iteration: 91500. Loss: 0.0. Accuracy: 84
# Iteration: 92000. Loss: 0.0. Accuracy: 84
# Iteration: 92500. Loss: 0.0. Accuracy: 84
# Iteration: 93000. Loss: 0.0. Accuracy: 84
# Iteration: 93500. Loss: 0.0. Accuracy: 84
# Iteration: 94000. Loss: 0.0. Accuracy: 84
# Iteration: 94500. Loss: 0.0. Accuracy: 84
# Iteration: 95000. Loss: 0.0. Accuracy: 84
# Iteration: 95500. Loss: 4.76837147544984e-09. Accuracy: 84
# Iteration: 96000. Loss: 3.7391186197055504e-05. Accuracy: 84
# Iteration: 96500. Loss: 4.684924988396233e-06. Accuracy: 84
# Iteration: 97000. Loss: 0.0. Accuracy: 84
# Iteration: 97500. Loss: 0.0. Accuracy: 84
# Iteration: 98000. Loss: 2.6226043559063328e-08. Accuracy: 84
# Iteration: 98500. Loss: 0.0. Accuracy: 84
# Iteration: 99000. Loss: 0.0. Accuracy: 84
# Iteration: 99500. Loss: 0.0. Accuracy: 84
# Iteration: 100000. Loss: 0.0. Accuracy: 84
# learning rate: 0.0001
# Iteration: 100500. Loss: 0.0. Accuracy: 84
# Iteration: 101000. Loss: 1.4305115314527939e-07. Accuracy: 84
# Iteration: 101500. Loss: 0.0. Accuracy: 84
# Iteration: 102000. Loss: 1.668930060816365e-08. Accuracy: 84
# Iteration: 102500. Loss: 2.38418573772492e-09. Accuracy: 84
# Iteration: 103000. Loss: 0.0. Accuracy: 84
# Iteration: 103500. Loss: 2.38418573772492e-09. Accuracy: 84
# Iteration: 104000. Loss: 0.0. Accuracy: 84
# Iteration: 104500. Loss: 9.53674295089968e-09. Accuracy: 84
# Iteration: 105000. Loss: 1.19209286886246e-09. Accuracy: 84
# Iteration: 105500. Loss: 0.0. Accuracy: 84
# Iteration: 106000. Loss: 4.76837147544984e-09. Accuracy: 84
# Iteration: 106500. Loss: 0.0. Accuracy: 84
# Iteration: 107000. Loss: 0.0. Accuracy: 84
# Iteration: 107500. Loss: 0.0. Accuracy: 84
# Iteration: 108000. Loss: 0.0. Accuracy: 84
# Iteration: 108500. Loss: 0.0. Accuracy: 84
# Iteration: 109000. Loss: 0.0. Accuracy: 84
# Iteration: 109500. Loss: 0.0. Accuracy: 84
# Iteration: 110000. Loss: 0.0. Accuracy: 84
# Iteration: 110500. Loss: 0.0. Accuracy: 84
# Iteration: 111000. Loss: 0.0. Accuracy: 84
# Iteration: 111500. Loss: 0.0. Accuracy: 84
# Iteration: 112000. Loss: 0.0. Accuracy: 84
# Iteration: 112500. Loss: 0.0. Accuracy: 84
# learning rate: 0.0001
# Iteration: 113000. Loss: 0.0. Accuracy: 84
# Iteration: 113500. Loss: 0.0. Accuracy: 84
# Iteration: 114000. Loss: 0.0. Accuracy: 84
# Iteration: 114500. Loss: 0.0. Accuracy: 84
# Iteration: 115000. Loss: 0.0. Accuracy: 84
# Iteration: 115500. Loss: 0.0. Accuracy: 84
# Iteration: 116000. Loss: 0.0. Accuracy: 84
# Iteration: 116500. Loss: 0.0. Accuracy: 84
# Iteration: 117000. Loss: 0.0. Accuracy: 84
# Iteration: 117500. Loss: 0.0. Accuracy: 84
# Iteration: 118000. Loss: 0.0. Accuracy: 84
# Iteration: 118500. Loss: 0.0. Accuracy: 84
# Iteration: 119000. Loss: 0.0. Accuracy: 84
# Iteration: 119500. Loss: 0.0. Accuracy: 84
# Iteration: 120000. Loss: 0.0. Accuracy: 84
# Iteration: 120500. Loss: 0.0. Accuracy: 84
# Iteration: 121000. Loss: 0.0. Accuracy: 84
# Iteration: 121500. Loss: 0.0. Accuracy: 84
# Iteration: 122000. Loss: 0.0. Accuracy: 84
# Iteration: 122500. Loss: 0.0. Accuracy: 84
# Iteration: 123000. Loss: 0.0. Accuracy: 84
# Iteration: 123500. Loss: 0.0. Accuracy: 84
# Iteration: 124000. Loss: 0.0. Accuracy: 84
# Iteration: 124500. Loss: 0.0. Accuracy: 84
# Iteration: 125000. Loss: 0.0. Accuracy: 84
# learning rate: 0.0001
# Iteration: 125500. Loss: 0.0. Accuracy: 84
# Iteration: 126000. Loss: 0.0. Accuracy: 84
# Iteration: 126500. Loss: 0.0. Accuracy: 84
# Iteration: 127000. Loss: 0.0. Accuracy: 84
# Iteration: 127500. Loss: 0.0. Accuracy: 84
# Iteration: 128000. Loss: 0.0. Accuracy: 84
# Iteration: 128500. Loss: 0.0. Accuracy: 84
# Iteration: 129000. Loss: 0.0. Accuracy: 84
# Iteration: 129500. Loss: 0.0. Accuracy: 84
# Iteration: 130000. Loss: 0.0. Accuracy: 84
# Iteration: 130500. Loss: 0.0. Accuracy: 84
# Iteration: 131000. Loss: 0.0. Accuracy: 84
# Iteration: 131500. Loss: 0.0. Accuracy: 84
# Iteration: 132000. Loss: 0.0. Accuracy: 84
# Iteration: 132500. Loss: 0.0. Accuracy: 84
# Iteration: 133000. Loss: 0.0. Accuracy: 84
# Iteration: 133500. Loss: 0.0. Accuracy: 84
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-7cb2005074a7> in <module>()
#      13
#      14         # Load images as Variable
# ---> 15         images = Variable(images).to(device)
#      16         labels = Variable(labels).to(device)
#      17
#
# KeyboardInterrupt:

# %%
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Test Accuracy of the model on the 10000 test images: 84.57 %

# %%
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in train_loader:
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    print('Test Accuracy of the model on the 50000 train images: {} %'.format(100 * correct / total))
# Out:
# Test Accuracy of the model on the 50000 train images: 100.0 %

# %% [markdown]
# ### Test memo:
#
#
# |dataset size(train/test)|#epoch|      model  |  optimizer | parameters |lr| accuracy(test/train)  |
# |-----------------------|-------|--------------|------------|------------|--|------------|
# |50000/10000|25|(conv - relu - conv- relu - pool)x2, Linearx1 |torch.optim.Adam|Kaiming He|0.001| 69.43%/ 88.28%|
# |50000/10000|25|(conv - relu - conv- relu - pool)x3, linear-relu-dropout-linear-dropout |torch.optim.Adam|Kaiming He|0.001| 70.83%/ 96.01%|
# |50000/10000|25|vgg16 |torch.optim.Adam|Kaiming He|0.001| 81.01%/  97.64%|
# |50000/10000|50|vgg16 |torch.optim.Adam|Kaiming He|0.001| 83.66%/  99.74%|
# |50000/10000|100|vgg16 |torch.optim.Adam|Kaiming He|0.001->(50epoch)0.0001|  83.71%/  100.0%|
# |50000/10000|250|vgg16 |torch.optim.Adam|Kaiming He|0.001->(150epoch)0.0001|  84.57%/  100.0%|

# %%
# Save the model checkpoint
torch.save(model.state_dict(), 'model_vgg.ckpt')

# %%
# Added dropout layer refers to http://torch.ch/blog/2015/07/30/cifar.html
